# %%
import pandas as pd

# %%
df = pd.read_csv('../../datasets/gapminder.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.to_string()
# Out:
# "                       country  year  population continent  life_exp        gdp_cap\n0                  Afghanistan  1952     8425333      Asia  28.80100     779.445314\n1                  Afghanistan  1957     9240934      Asia  30.33200     820.853030\n2                  Afghanistan  1962    10267083      Asia  31.99700     853.100710\n3                  Afghanistan  1967    11537966      Asia  34.02000     836.197138\n4                  Afghanistan  1972    13079460      Asia  36.08800     739.981106\n5                  Afghanistan  1977    14880372      Asia  38.43800     786.113360\n6                  Afghanistan  1982    12881816      Asia  39.85400     978.011439\n7                  Afghanistan  1987    13867957      Asia  40.82200     852.395945\n8                  Afghanistan  1992    16317921      Asia  41.67400     649.341395\n9                  Afghanistan  1997    22227415      Asia  41.76300     635.341351\n10                 Afghanistan  2002    25268405      Asia  42
# ...

# %%
df.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df.head(5)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df[['country', 'life_exp']]
# Out:
#           country  life_exp
# 0     Afghanistan    28.801
# 1     Afghanistan    30.332
# 2     Afghanistan    31.997
# 3     Afghanistan    34.020
# 4     Afghanistan    36.088
# ...           ...       ...
# 1699     Zimbabwe    62.351
# 1700     Zimbabwe    60.377
# 1701     Zimbabwe    46.809
# 1702     Zimbabwe    39.989
# 1703     Zimbabwe    43.487
#
# [1704 rows x 2 columns]

# %%
df.shape
# Out:
# (1704, 6)

# %%
x = df.head(2)
x
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
x.values.tolist()
# Out:
# [['Afghanistan', 1952, 8425333, 'Asia', 28.801, 779.4453145],
#  ['Afghanistan', 1957, 9240934, 'Asia', 30.332, 820.8530296]]

# %%
df["year"].values.tolist()
# Out:
# [1952,
#  1957,
#  1962,
#  1967,
#  1972,
#  1977,
#  1982,
#  1987,
#  1992,
#  1997,
#  2002,
#  2007,
#  1952,
#  1957,
#  1962,
#  1967,
#  1972,
#  1977,
#  1982,
#  1987,
#  1992,
#  1997,
#  2002,
#  2007,
#  1952,
#  1957,
#  1962,
#  1967,
#  1972,
#  1977,
#  1982,
#  1987,
#  1992,
#  1997,
#  2002,
#  2007,
#  1952,
#  1957,
#  1962,
#  1967,
#  1972,
#  1977,
#  1982,
#  1987,
#  1992,
#  1997,
#  2002,
#  2007,
#  1952,
#  1957,
#  1962,
#  1967,
#  1972,
#  1977,
#  1982,
#  1987,
#  1992,
#  1997,
#  2002,
#  2007,
#  1952,
#  1957,
#  1962,
#  1967,
#  1972,
#  1977,
#  1982,
#  1987,
#  1992,
#  1997,
#  2002,
#  2007,
#  1952,
#  1957,
#  1962,
#  1967,
#  1972,
#  1977,
#  1982,
#  1987,
#  1992,
#  1997,
#  2002,
#  2007,
#  1952,
#  1957,
#  1962,
#  1967,
#  1972,
#  1977,
#  1982,
#  1987,
#  1992,
#  1997,
#  2002,
#  2007,
#  1952,
#  1957,
#  1962,
#  1967,
#  1972,
#  1977,
#  1982,
#  1987,
#  1992,
#  1997,
#  2002,
#  2007,
#  1952,
#  1957,
#  1962,
# ...

# %%
df.keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df[df['country'] == 'Afghanistan']
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763  635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129  726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828  974.580338

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df['country'].nunique()
# Out:
# 142

# %%
des = df.describe()
des
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
des['year']
# Out:
# count    1704.00000
# mean     1979.50000
# std        17.26533
# min      1952.00000
# 25%      1965.75000
# 50%      1979.50000
# 75%      1993.25000
# max      2007.00000
# Name: year, dtype: float64

# %%
df['country'].value_counts().head()
# Out:
# Afghanistan    12
# Pakistan       12
# New Zealand    12
# Nicaragua      12
# Niger          12
# Name: country, dtype: int64

# %%
df.columns = ["Country", "Year", "Population", "Continent", "Life_exp", "Gdp_cap" ]

# %%
df
# Out:
#           Country  Year  Population Continent  Life_exp     Gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Population', 'Continent', 'Life_exp', 'Gdp_cap'], dtype='object')

# %%
df.rename?

# %%
df.drop?

# %%
df.drop('Year', axis=1)
# Out:
#           Country  Population Continent  Life_exp     Gdp_cap
# 0     Afghanistan     8425333      Asia    28.801  779.445314
# 1     Afghanistan     9240934      Asia    30.332  820.853030
# 2     Afghanistan    10267083      Asia    31.997  853.100710
# 3     Afghanistan    11537966      Asia    34.020  836.197138
# 4     Afghanistan    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# 1699     Zimbabwe     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df
# Out:
#           Country  Year  Population Continent  Life_exp     Gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.iloc[:20]
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763   635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# ...

# %%
df1 = pd.DataFrame([
    ["Jim", "M", "Athelete"],
    ["Came", "F", "Tech"],
    ["Chris", "M", "Cricketor"],
    ["Moms", "M", "Actor"]
], columns=["Name", "Gender", "Profession"])
df1
# Out:
#     Name Gender Profession
# 0    Jim      M   Athelete
# 1   Came      F       Tech
# 2  Chris      M  Cricketor
# 3   Moms      M      Actor

# %%
df1.iloc[:2,:2]
# Out:
#    Name Gender
# 0   Jim      M
# 1  Came      F

# %%
df1.loc[:2,"Name":"Profession"]
# Out:
#     Name Gender Profession
# 0    Jim      M   Athelete
# 1   Came      F       Tech
# 2  Chris      M  Cricketor

# %%
pd.DataFrame(df1, columns=['Gender', 'Name', 'Profession'])
# Out:
#   Gender   Name Profession
# 0      M    Jim   Athelete
# 1      F   Came       Tech
# 2      M  Chris  Cricketor
# 3      M   Moms      Actor

# %%
df1[['Gender', 'Profession', 'Name']]
# Out:
#   Gender Profession   Name
# 0      M   Athelete    Jim
# 1      F       Tech   Came
# 2      M  Cricketor  Chris
# 3      M      Actor   Moms

# %%
df1.loc[:, ['Gender', 'Profession', 'Name']]
# Out:
#   Gender Profession   Name
# 0      M   Athelete    Jim
# 1      F       Tech   Came
# 2      M  Cricketor  Chris
# 3      M      Actor   Moms

# %%
df.set_index?

# %%
df1['Name'].is_unique

# %%
df1.drop?

# %%
for x in df1.columns:
    if df1[x].nunique()==1:
        df.drop(x, axis=1, inplace=True)
        
df1
# Out:
#     Name Gender Profession
# 0    Jim      M   Athelete
# 1   Came      F       Tech
# 2  Chris      M  Cricketor
# 3   Moms      M      Actor

# %%
str = "The king has to meet the king of other state with the queen"

pd.value_counts(str.split(" "), sort=True)
# Out:
# king     2
# the      2
# The      1
# has      1
# to       1
# meet     1
# of       1
# other    1
# state    1
# with     1
# queen    1
# dtype: int64
