# %%
import pandas as pd

# %%
df = pd.read_csv('../../datasets/gapminder.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.iloc[4:5]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[1]
# Out:
# country       Afghanistan
# year                 1957
# population        9240934
# continent            Asia
# life_exp           30.332
# gdp_cap         820.85303
# Name: 1, dtype: object

# %%
df.iloc[[2,5,1703]]
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.loc[[2,5,1703], ['country', 'year']]
# Out:
#           country  year
# 2     Afghanistan  1962
# 5     Afghanistan  1977
# 1703     Zimbabwe  2007

# %%
df.iloc[3:5,2:4]
# Out:
#    population continent
# 3    11537966      Asia
# 4    13079460      Asia

# %%
df.iloc[3:6]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360

# %%
df.iloc[2:10, [0,1,3]]
# Out:
#        country  year continent
# 2  Afghanistan  1962      Asia
# 3  Afghanistan  1967      Asia
# 4  Afghanistan  1972      Asia
# 5  Afghanistan  1977      Asia
# 6  Afghanistan  1982      Asia
# 7  Afghanistan  1987      Asia
# 8  Afghanistan  1992      Asia
# 9  Afghanistan  1997      Asia

# %%
df.iloc[[1703,2,99], -3:]
# Out:
#      continent  life_exp     gdp_cap
# 1703    Africa    43.487  469.709298
# 2         Asia    31.997  853.100710
# 99        Asia    43.453  721.186086

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 df.iloc[1707]= ["Zimbabwe",2007,12311143,"Africa",43.487,469.709298]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:713, in _LocationIndexer.__setitem__(self, key, value)
#     711     key = com.apply_if_callable(key, self.obj)
#     712 indexer = self._get_setitem_indexer(key)
# --> 713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
#     716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1413, in _iLocIndexer._has_valid_setitem_indexer(self, indexer)
#    1411 elif is_integer(i):
#    1412     if i >= len(ax):
# -> 1413         raise IndexError("iloc cannot enlarge its target object")
#    1414 elif isinstance(i, dict):
# ...

# %%
df = pd.DataFrame({'emp_id':[1, 2], 'name': ['Ram', 'Shyam'], 'dept':['IT', 'Ops']})
df
# Out:
#    emp_id   name dept
# 0       1    Ram   IT
# 1       2  Shyam  Ops

# %%
df.T
# Out:
#           0      1
# emp_id    1      2
# name    Ram  Shyam
# dept     IT    Ops

# %%
df
# Out:
#    emp_id   name dept
# 0       1    Ram   IT
# 1       2  Shyam  Ops

# %%
df.loc[3]=[3, 'Bhim', 'SD']

# %%
df
# Out:
#    emp_id   name dept
# 0       1    Ram   IT
# 1       2  Shyam  Ops
# 3       3   Bhim   SD

# %%
df.T
# Out:
#           0      1     3
# emp_id    1      2     3
# name    Ram  Shyam  Bhim
# dept     IT    Ops    SD

# %%
df.loc[5]=[3, 'Bhim', 'SD']

# %%
df.T
# Out:
#           0      1     3     4     5
# emp_id    1      2     3     3     3
# name    Ram  Shyam  Bhim  Bhim  Bhim
# dept     IT    Ops    SD    SD    SD

# %%
df.drop_duplicates(keep ="first")
# Out:
#    emp_id   name dept
# 0       1    Ram   IT
# 1       2  Shyam  Ops
# 3       3   Bhim   SD

# %%
df
# Out:
#       name  marks
# 0    Luffy     15
# 1  Chopper     89
# 2     Zoro     33
# 3    Sanji     32

# %%
dfFilter = df['continent'] == 'Asia'
df.loc[dfFilter]
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088   739.981106
# ...           ...   ...         ...       ...       ...          ...
# 1675  Yemen, Rep.  1987    11219340      Asia    52.922  1971.741538
# 1676  Yemen, Rep.  1992    13367997      Asia    55.599  1879.496673
# 1677  Yemen, Rep.  1997    15826497      Asia    58.020  2117.484526
# 1678  Yemen, Rep.  2002    18701257      Asia    60.308  2234.820827
# 1679  Yemen, Rep.  2007    22211743      Asia    62.698  2280.769906
#
# [396 rows x 6 columns]

# %%
df['year'] >= 1980
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699     True
# 1700     True
# 1701     True
# 1702     True
# 1703     True
# Name: year, Length: 1704, dtype: bool

# %%
df = pd.DataFrame([['Luffy', 15], ['Chopper', 89], ['Zoro', 33], ['Sanji', 32]], columns=['name', 'marks'])
df
# Out:
#       name  marks
# 0    Luffy     15
# 1  Chopper     89
# 2     Zoro     33
# 3    Sanji     32

# %%
df.name.loc[df['marks']>=33]
# Out:
# 1    Chopper
# 2       Zoro
# Name: name, dtype: object

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df[['country', 'year']].loc[df['year']>=1992]
# Out:
#           country  year
# 8     Afghanistan  1992
# 9     Afghanistan  1997
# 10    Afghanistan  2002
# 11    Afghanistan  2007
# 20        Albania  1992
# ...           ...   ...
# 1691       Zambia  2007
# 1700     Zimbabwe  1992
# 1701     Zimbabwe  1997
# 1702     Zimbabwe  2002
# 1703     Zimbabwe  2007
#
# [568 rows x 2 columns]

# %%
df[['year']].loc[df['country'] == 'Zambia']
# Out:
#       year
# 1680  1952
# 1681  1957
# 1682  1962
# 1683  1967
# 1684  1972
# 1685  1977
# 1686  1982
# 1687  1987
# 1688  1992
# 1689  1997
# 1690  2002
# 1691  2007
