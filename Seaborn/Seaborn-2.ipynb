# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris= sns.load_dataset('iris')
tips= sns.load_dataset('tips')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris['species'].nunique()
# Out:
# 3

# %%
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.countplot(data=iris, x="species")
plt.show()

# %%
sns.countplot(data=tips, x="smoker")
plt.show()

# %%
sns.scatterplot(data=iris, x='petal_length', y='petal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.scatterplot(data=iris, x='petal_length', y='petal_width', hue="species")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips, x="sex", y='total_bill', hue="sex")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.jointplot(data=iris, x="petal_length", y="petal_width", hue="species")

# %%
sns.jointplot(data=iris, x="petal_length", y="petal_width", kind="reg")

# %%
sns.jointplot(data=iris, x="petal_length", y="petal_width", kind="hist")

# %%
sns.jointplot(data=iris, x="petal_length", y="petal_width")

# %%
sns.jointplot(data=iris, x="petal_length", y="petal_width", kind="hex")

# %%
sns.pairplot(data=iris)

# %%
sns.pairplot(data=iris, hue="species")

# %%
data = np.array([1,1,1,2,2,3,3,4,4,6,7,8,10,11,11, 15,20,22,25])

# %%
np.median(data)
# Out:
# 6.0

# %%
# 25 % = 2, 50% = 6, 75% = 11

# %%
IQR = 13.5
top_whisker = 11 + 13.5
bottom_whisker = 2 - 13.5

# %%
data
# Out:
# array([ 1,  1,  1,  2,  2,  3,  3,  4,  4,  6,  7,  8, 10, 11, 11, 15, 20,
#        22, 25])

# %%
np.percentile(data, 25)
# Out:
# 2.5

# %%
np.percentile(data, 50)
# Out:
# 6.0

# %%
np.percentile(data, 75)
# Out:
# 11.0

# %%
sns.boxplot(data, notch=True, )
# Out:
# C:\Users\Sibaram Sahu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.violinplot(data)
# Out:
# C:\Users\Sibaram Sahu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.boxplot(data=iris, x="sepal_length", y="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=iris, x='sepal_length', y='sepal_width', hue="species")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.countplot(data=tips, x='sex', hue="smoker")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.barplot(data=tips, x='day', y="total_bill")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips, x='day', y="total_bill",hue="sex" )
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips, x='day', y="total_bill",hue="smoker" )
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot(data=tips, x='tip', y="total_bill",hue="sex", size="size" )
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(data=titanic, x="age", y="sex")
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
titanic_third_class = titanic[(titanic['pclass']== 3)]

# %%
sns.countplot(data=titanic_third_class, x="survived")
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(data=titanic, x="alone",y="age", hue="survived")
# Out:
# <AxesSubplot:xlabel='alone', ylabel='age'>

# %%
sns.countplot(data=titanic, x="survived",hue="sex")
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
sns.boxplot(data=titanic, x="age")
# Out:
# <AxesSubplot:xlabel='age'>
