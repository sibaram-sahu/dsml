# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x_val = [0,1,2]
y_val = [3, 6, 10]
plt.plot(x_val, y_val)
plt.show()

# %%
x_val = [0,1,2]
y_val = [3, 6, 10]
plt.plot(x_val, y_val, 'o')
plt.show()
